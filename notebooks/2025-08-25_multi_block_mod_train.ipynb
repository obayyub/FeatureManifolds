# %%
# %load_ext autoreload
# %autoreload 2
import featureman.gen_data as man
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import Dataset, DataLoader

# %%
# seed
torch.manual_seed(1337)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = man.MultiLayerTransformer(p=113, d_model=128, n_layers=3).to(device)

dataset = man.ModularArithmeticDataset(p=113, n_samples=113**2)
train_size = int(0.3 * len(dataset))
test_size = len(dataset) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(
    dataset, [train_size, test_size]
)
#full batch size
train_dataloader = DataLoader(train_dataset, batch_size=113**2, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=113**2, shuffle=False)

optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1, betas=(0.9, 0.98))
criterion = nn.CrossEntropyLoss()

# %%
# Track losses
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

# Training loop
for epoch in range(20000):
    # Training
    model.train()
    epoch_train_loss = 0
    correct = 0
    total = 0

    for batch_idx, batch in enumerate(train_dataloader):
        optimizer.zero_grad()

        # The batch is a dictionary with keys, not a list of dictionaries
        input_ids = batch["inputs"].long().to(device)
        labels = batch["labels"].long().to(device)

        logits = model(input_ids)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        epoch_train_loss += loss.item()
        _, predicted = torch.max(logits, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

        if batch_idx % 100 == 0:
            print(f"Epoch {epoch}, Batch {batch_idx}, Loss: {loss.item():.4f}")

    # Testing
    model.eval()
    epoch_test_loss = 0
    test_correct = 0
    test_total = 0

    with torch.no_grad():
        for batch in test_dataloader:
            input_ids = batch["inputs"].long().to(device)
            labels = batch["labels"].long().to(device)

            logits = model(input_ids)
            loss = criterion(logits, labels)

            epoch_test_loss += loss.item()
            _, predicted = torch.max(logits, 1)
            test_correct += (predicted == labels).sum().item()
            test_total += labels.size(0)

    # Calculate averages
    avg_train_loss = epoch_train_loss / len(train_dataloader)
    avg_test_loss = epoch_test_loss / len(test_dataloader)
    train_acc = 100 * correct / total
    test_acc = 100 * test_correct / test_total

    if test_acc == 100.0:
        print(f"Training accuracy reached 100% at epoch {epoch}. Stopping training.")
        break

    # Store metrics
    train_losses.append(avg_train_loss)
    test_losses.append(avg_test_loss)
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)

    print(f"\nEpoch {epoch} Summary:")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_acc:.2f}%")
    print(f"Test Loss: {avg_test_loss:.4f}, Test Acc: {test_acc:.2f}%")
    print("-" * 50)

print("\nTraining Complete!")
print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
# Out:
# Epoch 0, Batch 0, Loss: 4.9680
#
# Epoch 0 Summary:
# Train Loss: 4.9680, Train Acc: 0.78%
# Test Loss: 4.7907, Test Acc: 0.91%
# --------------------------------------------------
# Epoch 1, Batch 0, Loss: 4.7766
#
# Epoch 1 Summary:
# Train Loss: 4.7766, Train Acc: 0.73%
# Test Loss: 4.7933, Test Acc: 0.78%
# --------------------------------------------------
# Epoch 2, Batch 0, Loss: 4.7446
#
# Epoch 2 Summary:
# Train Loss: 4.7446, Train Acc: 1.15%
# Test Loss: 4.7812, Test Acc: 0.95%
# --------------------------------------------------
# Epoch 3, Batch 0, Loss: 4.7147
#
# Epoch 3 Summary:
# Train Loss: 4.7147, Train Acc: 1.64%
# Test Loss: 4.7713, Test Acc: 1.10%
# --------------------------------------------------
# Epoch 4, Batch 0, Loss: 4.6897
#
# Epoch 4 Summary:
# Train Loss: 4.6897, Train Acc: 2.11%
# Test Loss: 4.7653, Test Acc: 0.93%
# --------------------------------------------------
# Epoch 5, Batch 0, Loss: 4.6652
#
# Epoch 5 Summary:
# ...

# %%
#side by side plot of train/test accuracies and losses
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train/Test Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train/Test Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#save the model
torch.save(model.state_dict(), "multi_layer_modular_arithmetic_model.pth")
print("Model saved as multi_layer_modular_arithmetic_model.pth")
# Out:
# Model saved as multi_layer_modular_arithmetic_model.pth

# %%
embed_weights = model.embedding.weight.detach().cpu().numpy()
#imshow
plt.figure(figsize=(10, 8))
plt.imshow(embed_weights, aspect='auto', cmap='viridis')
plt.colorbar()
plt.title('Embedding Weights Visualization')
plt.xlabel('Embedding Dimension')
plt.ylabel('Input Token Index')
plt.show()
